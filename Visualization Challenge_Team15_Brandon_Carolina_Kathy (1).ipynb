# %% [markdown]
# ## Scatterplot

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

path = 'C:\\Users\\kjhm\\Documents\\QMB3302\\Data Sets\\vaccination data.csv'
seg = pd.read_csv(path)
seg.head(43439)
# Out:
#           location iso_code       date  total_vaccinations  people_vaccinated  \
# 0      Afghanistan      AFG  2/22/2021                 0.0                0.0
# 1      Afghanistan      AFG  2/23/2021                 NaN                NaN
# 2      Afghanistan      AFG  2/24/2021                 NaN                NaN
# 3      Afghanistan      AFG  2/25/2021                 NaN                NaN
# 4      Afghanistan      AFG  2/26/2021                 NaN                NaN
# ...            ...      ...        ...                 ...                ...
# 43434     Zimbabwe      ZWE  8/24/2021           3889424.0          2382059.0
# 43435     Zimbabwe      ZWE  8/25/2021           4015517.0          2453229.0
# 43436     Zimbabwe      ZWE  8/26/2021                 NaN                NaN
# 43437     Zimbabwe      ZWE  8/27/2021           4075995.0          2491680.0
# 43438     Zimbabwe      ZWE  8/28/2021           4110354.0          2513053.0
#
# ...

# %%
seg.dropna()
# Out:
#       location  iso_code       date  total_vaccinations  people_vaccinated  \
# 2343      Asia  OWID_ASI  6/30/2021        1.907441e+09       1.117657e+09
# 2344      Asia  OWID_ASI   7/1/2021        1.940588e+09       1.129037e+09
# 2345      Asia  OWID_ASI   7/2/2021        1.965228e+09       1.132271e+09
# 2346      Asia  OWID_ASI   7/3/2021        1.991445e+09       1.141391e+09
# 2347      Asia  OWID_ASI   7/4/2021        2.009793e+09       1.147507e+09
# ...        ...       ...        ...                 ...                ...
# 43025    World  OWID_WRL  8/24/2021        5.049527e+09       2.999932e+09
# 43026    World  OWID_WRL  8/25/2021        5.092489e+09       3.015711e+09
# 43027    World  OWID_WRL  8/26/2021        5.136240e+09       3.090383e+09
# 43028    World  OWID_WRL  8/27/2021        5.182764e+09       3.108159e+09
# 43029    World  OWID_WRL  8/28/2021        5.213176e+09       3.118470e+09
#
# ...

# %%
sns.lmplot(x='total_vaccinations_per_hundred', y='people_fully_vaccinated_per_hundred', data=seg)

# %% [markdown]
# The scatterplot shown below compares total vaccinations to fully vaccinations and the strong positive correlation that the majority of people who get vaccinated in general are getting fully  vaccinated. With our immense amount of data points, this is one the graphs that we found to be visually representative of our data.

# %% [markdown]
# ## Jointplot

# %%
sns.jointplot(x='total_vaccinations_per_hundred', y='people_fully_vaccinated_per_hundred', data=seg, kind = 'scatter')

# %% [markdown]
# The below joint plot is an adaptation of our scatterplot but also shows the vast prevalence of data points in the earlier range of the x and y axis (total vaccination per hundred vs. people fully vaccinated per hundred). Not immediately apparent in our previous scatterplot, as the whole graph looks dense, most countries have quite a low vaccination rate per hundred, but with an increasing amount of vaccination in general, the higher the rate of which people become fully vaccinated. The statistical point this joint plot raises is the existence of a large amount of countries who are just not getting a high percentage of people vaccinated per population parameters.

# %% [markdown]
# ## Heatmap

# %%
seg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43439 entries, 0 to 43438
# Data columns (total 14 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             43439 non-null  object
#  1   iso_code                             43439 non-null  object
#  2   date                                 43439 non-null  object
#  3   total_vaccinations                   25214 non-null  float64
#  4   people_vaccinated                    24232 non-null  float64
#  5   people_fully_vaccinated              21158 non-null  float64
#  6   total_boosters                       513 non-null    float64
#  7   daily_vaccinations_raw               21211 non-null  float64
#  8   daily_vaccinations                   43172 non-null  float64
#  9   total_vaccinations_per_hundred       25214 non-null  float64
#  10  people_vaccinated_per_hundred        24232 non-null  float64
# ...

# %%
corr = seg.corr()
corr
# Out:
#                                      total_vaccinations  people_vaccinated  \
# total_vaccinations                             1.000000           0.989604
# people_vaccinated                              0.989604           1.000000
# people_fully_vaccinated                        0.958326           0.970446
# total_boosters                                 0.673530           0.673248
# daily_vaccinations_raw                         0.904535           0.884721
# daily_vaccinations                             0.924427           0.904486
# total_vaccinations_per_hundred                 0.104559           0.084716
# people_vaccinated_per_hundred                  0.073166           0.077579
# people_fully_vaccinated_per_hundred            0.028176           0.027998
# total_boosters_per_hundred                    -0.394060          -0.391787
# daily_vaccinations_per_million                 0.066720           0.045014
#
# ...

# %%
plt.subplots(figsize=(10,10))
sns.heatmap(corr, annot=True, fmt='0.1f', square=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# This plot was chosen because of the interest in what a heat map could show us in our data. As you can tell from below there is an immense number of comparable variables, but in general the comparisons of the data types showed correlation i.e. all of the ‘per hundred’ data were comparable and correlated, but the when comparing a large number to a ‘per hundred’ value resulted in very poor correlation due to the difference in the data types. Our group liked the heatmap because it was able to take all of our data and display it in a friendly format that took only took a little bit of time to decipher.

# %% [markdown]
# ## Countplot

# %%
sns.countplot(x='people_fully_vaccinated', data=seg)
# Out:
# <AxesSubplot:xlabel='people_fully_vaccinated', ylabel='count'>

# %% [markdown]
# This was one of the plots that was quite challenge to make work, and after trying multiple times, we realized our data was not easily displayed using this method. The chart below represents one of our attempts to display people fully vaccinated across all our country data points, but due to the sheer number of countries, it is near impossible to tell any trends. We also tried other variables to compare but without trimming down to a comparison of say 3-4 countries against each other, it is quite hard displaying our data in this fashion.

# %% [markdown]
# # Conclusion

# %% [markdown]
# During the data wrangling challenge and in this challenge, our group found our data to be not very friendly in terms of visually graphing variable to discover trends and valuable statistical data. It was definitely a challenge to try to work around our data, but we were able to populate the different graphs you see in this assignment after some time.
